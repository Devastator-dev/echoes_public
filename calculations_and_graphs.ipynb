# %% [markdown]
# Calculation of havoc rover without equipped echoes with emerald of genesis r1

# %%
import echoes_main as ech
import additional_functions as addfun
import damage_functions as dmgfun


import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import cProfile as cp
import characters as char

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_echo_farming(15,5,char.Shorekeeper,
                                                            ech.field_set_mr_rg,ech.set_rg,ech.desired_mainstats_list_shore,dmgfun.calculate_shorekeeper_build_quality,is_support=True,save_plots=True,print_character=True)
# Out:
# 0.0 %  done
# Name:  Shorekeeper
#  Total hp:  46248.74699999995
#  Total atk:  1284.375
#  Total def:  1100.0
#  Crit rate:  21.19999999999999 %
#  Crit damage:  219.60000000000002 %
#  Energy recharge:  239.0 %
#  Elemental damage bonus:  0 %
#  Healing bonus:  22 %
#  Basic attack damage bonus:  23.2 %
#  Heavy attack damage bonus:  0.0 %
#  Ultimate damage bonus:  0.0 %
#  Skill damage bonus:  8.6 %
#  Weapon:  variation
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H09
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [30]   sub_ATK
#
# [430]   sub_HP
#
# [19.8]   sub_CD
#
# [8.1]   sub_CR
#
# [10.1]   sub_HP%
#
# Name:  W63
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [10.1]   sub_HP%
#
# [11.6]   sub_ba_DMG
#
# [10.1]   sub_ATK%
#
# [11.6]   sub_ER
#
# [17.4]   sub_CD
#
# Name:  W63
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [10.1]   sub_HP%
#
# [11.6]   sub_ba_DMG
#
# [10.1]   sub_ATK%
#
# [11.6]   sub_ER
#
# [17.4]   sub_CD
#
# Name:  X78
#  Set:  Healing_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'HP%')
# Substats:
# [8.6]   sub_sk_DMG
#
# [470]   sub_HP
#
# [15]   sub_CD
#
# [9.4]   sub_HP%
#
# [7.9]   sub_ATK%
#
# Name:  S08
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [8.1]   sub_CR
#
# [360]   sub_HP
#
# [50]   sub_ATK
#
# [8.6]   sub_ATK%
#
# [11.6]   sub_HP%
#
# Echo exp materials needed (golden):  6238.5599999999995
# Estimated tacet field runs needed for exp:  1492.4784688995214
# Estimated days to get that exp:  373.11961722488036
#
# Tuners needed:  15540
# Estimated tacet field runs needed for tuners:  621.6
# Estimated days to get that tuners:  155.4
# 20.0 %  done
# Name:  Shorekeeper
#  Total hp:  45481.06099999997
#  Total atk:  1153.125
#  Total def:  1150.0
#  Crit rate:  39.2 %
#  Crit damage:  202.2 %
#  Energy recharge:  235.0 %
#  Elemental damage bonus:  0 %
#  Healing bonus:  22 %
#  Basic attack damage bonus:  23.700000000000017 %
#  Heavy attack damage bonus:  7.900000000000004 %
#  Ultimate damage bonus:  8.6 %
#  Skill damage bonus:  0.0 %
#  Weapon:  variation
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  G02
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [8.6]   sub_HP%
#
# [10]   sub_ER
#
# [7.5]   sub_CR
#
# [430]   sub_HP
#
# [6.4]   sub_ba_DMG
#
# Name:  W63
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [18.6]   sub_CD
#
# [9.2]   sub_ER
#
# [9.9]   sub_CR
#
# [9.4]   sub_ba_DMG
#
# [8.6]   sub_HP%
#
# Name:  X78
#  Set:  Healing_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'HP%')
# Substats:
# [15]   sub_CD
#
# [10.9]   sub_HP%
#
# [8.1]   sub_CR
#
# [50]   sub_DEF
#
# [60]   sub_ATK
#
# Name:  W63
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [10.1]   sub_HP%
#
# [7.9]   sub_he_DMG
#
# [430]   sub_HP
#
# [10.9]   sub_ATK%
#
# [50]   sub_ATK
#
# Name:  X54
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [10.9]   sub_HP%
#
# [18.6]   sub_CD
#
# [8.6]   sub_ult_DMG
#
# [8.7]   sub_CR
#
# [7.9]   sub_ba_DMG
#
# Echo exp materials needed (golden):  6206.92
# Estimated tacet field runs needed for exp:  1484.909090909091
# Estimated days to get that exp:  371.22727272727275
#
# Tuners needed:  15460
# Estimated tacet field runs needed for tuners:  618.4
# Estimated days to get that tuners:  154.6
# 40.0 %  done
# Name:  Shorekeeper
#  Total hp:  46884.070000000094
#  Total atk:  1078.125
#  Total def:  1199.0
#  Crit rate:  23.0 %
#  Crit damage:  202.2 %
#  Energy recharge:  234.20000000000002 %
#  Elemental damage bonus:  0 %
#  Healing bonus:  22 %
#  Basic attack damage bonus:  8.6 %
#  Heavy attack damage bonus:  10.1 %
#  Ultimate damage bonus:  28.099999999999994 %
#  Skill damage bonus:  0.0 %
#  Weapon:  variation
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  W62
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [430]   sub_HP
#
# [17.4]   sub_CD
#
# [8.6]   sub_ult_DMG
#
# [7.5]   sub_CR
#
# [7.9]   sub_HP%
#
# Name:  H42
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [10.9]   sub_HP%
#
# [18.6]   sub_CD
#
# [9]   sub_DEF%
#
# [580]   sub_HP
#
# [10]   sub_ER
#
# Name:  W30
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [40]   sub_ATK
#
# [7.9]   sub_HP%
#
# [430]   sub_HP
#
# [8.4]   sub_ER
#
# [10.5]   sub_CR
#
# Name:  X78
#  Set:  Healing_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'HP%')
# Substats:
# [10.1]   sub_he_DMG
#
# [16.2]   sub_CD
#
# [10.1]   sub_HP%
#
# [430]   sub_HP
#
# [8.6]   sub_ult_DMG
#
# Name:  H21
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [10.9]   sub_ult_DMG
#
# [8.6]   sub_ba_DMG
#
# [11.6]   sub_HP%
#
# [510]   sub_HP
#
# [10.1]   sub_ATK%
#
# Echo exp materials needed (golden):  6165.060000000001
# Estimated tacet field runs needed for exp:  1474.8947368421057
# Estimated days to get that exp:  368.7236842105264
#
# Tuners needed:  15300
# Estimated tacet field runs needed for tuners:  612.0
# Estimated days to get that tuners:  153.0
# 60.0 %  done
# Name:  Shorekeeper
#  Total hp:  46602.45099999992
#  Total atk:  1228.75
#  Total def:  1600.6000000000001
#  Crit rate:  19.399999999999995 %
#  Crit damage:  166.2 %
#  Energy recharge:  235.8 %
#  Elemental damage bonus:  0 %
#  Healing bonus:  22 %
#  Basic attack damage bonus:  0 %
#  Heavy attack damage bonus:  0.0 %
#  Ultimate damage bonus:  7.899999999999993 %
#  Skill damage bonus:  0.0 %
#  Weapon:  variation
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H91
#  Set:  Healing_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'HP%')
# Substats:
# [7.9]   sub_ult_DMG
#
# [7.9]   sub_ATK%
#
# [430]   sub_HP
#
# [30]   sub_ATK
#
# [10.1]   sub_HP%
#
# Name:  H49
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [10]   sub_ER
#
# [10.1]   sub_HP%
#
# [50]   sub_ATK
#
# [12.8]   sub_DEF%
#
# [8.1]   sub_CR
#
# Name:  S08
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [510]   sub_HP
#
# [6.3]   sub_CR
#
# [70]   sub_DEF
#
# [10.9]   sub_HP%
#
# [10.9]   sub_DEF%
#
# Name:  S55
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [7.1]   sub_ATK%
#
# [16.2]   sub_CD
#
# [40]   sub_ATK
#
# [10]   sub_ER
#
# [10.1]   sub_HP%
#
# Name:  S09
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [50]   sub_DEF
#
# [40]   sub_ATK
#
# [540]   sub_HP
#
# [10.9]   sub_HP%
#
# [10.9]   sub_DEF%
#
# Echo exp materials needed (golden):  6486.079999999999
# Estimated tacet field runs needed for exp:  1551.693779904306
# Estimated days to get that exp:  387.9234449760765
#
# Tuners needed:  16220
# Estimated tacet field runs needed for tuners:  648.8
# Estimated days to get that tuners:  162.2
# 80.0 %  done
# Name:  Shorekeeper
#  Total hp:  46868.46900000005
#  Total atk:  1163.125
#  Total def:  1329.0
#  Crit rate:  13.700000000000001 %
#  Crit damage:  195.0 %
#  Energy recharge:  235.00000000000003 %
#  Elemental damage bonus:  0 %
#  Healing bonus:  22 %
#  Basic attack damage bonus:  0.0 %
#  Heavy attack damage bonus:  1.7763568394002505e-15 %
#  Ultimate damage bonus:  7.9 %
#  Skill damage bonus:  7.9 %
#  Weapon:  variation
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H42
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [9.4]   sub_HP%
#
# [7.9]   sub_ATK%
#
# [8.4]   sub_ER
#
# [16.2]   sub_CD
#
# [50]   sub_ATK
#
# Name:  H12
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [15]   sub_CD
#
# [10.1]   sub_HP%
#
# [7.9]   sub_ult_DMG
#
# [8.7]   sub_CR
#
# [540]   sub_HP
#
# Name:  H91
#  Set:  Healing_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'HP%')
# Substats:
# [13.8]   sub_CD
#
# [9.4]   sub_HP%
#
# [10.8]   sub_ER
#
# [40]   sub_DEF
#
# [470]   sub_HP
#
# Name:  H12
#  Set:  Healing_s
#  Cost:  1
#  Mainstats:  ([22.8, 2280], 'HP%')
# Substats:
# [10.9]   sub_HP%
#
# [580]   sub_HP
#
# [30]   sub_ATK
#
# [50]   sub_DEF
#
# [7.9]   sub_sk_DMG
#
# Name:  W62
#  Set:  Healing_s
#  Cost:  3
#  Mainstats:  ([32, 100], 'ER')
# Substats:
# [390]   sub_HP
#
# [9]   sub_DEF%
#
# [9.4]   sub_ATK%
#
# [10.9]   sub_HP%
#
# [40]   sub_DEF
#
# Echo exp materials needed (golden):  6224.140000000001
# Estimated tacet field runs needed for exp:  1489.0287081339716
# Estimated days to get that exp:  372.2571770334929
#
# Tuners needed:  15490
# Estimated tacet field runs needed for tuners:  619.6
# Estimated days to get that tuners:  154.9

# %%
"""'Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
Rover_Havoc._apply_weapon_conditional_bonuses()
damage=[]

Rover_Havoc._total_attack+=(94/100)*Rover_Havoc._base_atk
Rover_Havoc._total_cd+=149
Rover_Havoc._total_cr+=52.5
Rover_Havoc._total_attack+=700
Rover_Havoc._ult_dmg+=58
Rover_Havoc._total_elem_dmg=112

Rover_Havoc.print_character_stats()

for i in range(1000):
    damage.append(dmgfun.calculate_hrover_combo_damage(Rover_Havoc))

print(damage)

fig,ax=plt.subplots()
ax.hist(damage,bins=30)
ax.set(title='Number of occurances of specific damage with max stats, 1000 tries',xlabel='damage',ylabel='number of occurances')
plt.savefig('Output/Graphs/max damage.png',format='png')

fig,ax=plt.subplots()
ax.plot(np.cumsum(list_of_days),average_damages_through_days,'.')
titstr='Damage during '+str(np.sum(list_of_days))+' days with max theoretical damage and its average for reference, hrover'
ax.set(title=titstr,xlabel='day',ylabel='damage')
ax.plot(10,max(damage),'ro')
ax.plot(10,np.mean(damage),'mo')
plt.savefig('Output/Graphs/'+titstr+'.png')"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
#       2 Rover_Havoc._apply_weapon_conditional_bonuses()
#       3 damage=[]
#
# NameError: name 'ech' is not defined
