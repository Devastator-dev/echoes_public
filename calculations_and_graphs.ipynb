# %% [markdown]
# Calculation of havoc rover without equipped echoes with emerald of genesis r1

# %%
import echoes_main as ech
import additional_functions as addfun
import damage_functions as dmgfun


import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import cProfile as cp
import characters as char

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_echo_farming(55,5,char.Shorekeeper,
                                                            ech.field_set_mr_rg,ech.set_rg,ech.desired_mainstats_list_shore,
                                                            dmgfun.calculate_shorekeeper_build_quality,is_support=True,save_plots=True)

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_echo_farming(5,2,char.Rover_Havoc,
                                                            ech.field_set_sse_mc,ech.set_sse,ech.desired_mainstats_list_havoc_dps,
                                                            dmgfun.calculate_hrover_combo_damage,is_support=False,do_overworld_farming=True,
                                                            do_tacet_field_farming=True,do_boss_farming=True,amount_of_farming=0.5,save_plots=True)
# Out:
# 0.0 %  done
# Echo exp materials needed (golden):  7702.76
# Estimated tacet field runs needed for exp:  1842.7655502392347
# Estimated days to get that exp:  460.6913875598087
#
# Tuners needed:  19380
# Estimated tacet field runs needed for tuners:  775.2
# Estimated days to get that tuners:  193.8
# 50.0 %  done
# Echo exp materials needed (golden):  7715.78
# Estimated tacet field runs needed for exp:  1845.8803827751196
# Estimated days to get that exp:  461.4700956937799
#
# Tuners needed:  19440
# Estimated tacet field runs needed for tuners:  777.6
# Estimated days to get that tuners:  194.4

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_echo_farming(55,5,char.Xiangli_Yao,
                                                            ech.field_set_ff_vt,ech.set_vt,ech.desired_mainstats_list_electro_dps,
                                                            dmgfun.calculate_xiangli_combo_damage,is_support=False,save_plots=True)
# Out:
# 0.0 %  done
# Echo exp materials needed (golden):  19749.639999999996
# Estimated tacet field runs needed for exp:  4724.794258373205
# Estimated days to get that exp:  1181.1985645933012
#
# Tuners needed:  49110
# Estimated tacet field runs needed for tuners:  1964.4
# Estimated days to get that tuners:  491.1
# 20.0 %  done
# Echo exp materials needed (golden):  19905.039999999986
# Estimated tacet field runs needed for exp:  4761.971291866026
# Estimated days to get that exp:  1190.4928229665065
#
# Tuners needed:  49530
# Estimated tacet field runs needed for tuners:  1981.2
# Estimated days to get that tuners:  495.3
# 40.0 %  done
# Echo exp materials needed (golden):  20113.499999999985
# Estimated tacet field runs needed for exp:  4811.842105263155
# Estimated days to get that exp:  1202.9605263157887
#
# Tuners needed:  50030
# Estimated tacet field runs needed for tuners:  2001.2
# Estimated days to get that tuners:  500.3
# 60.0 %  done
# ...

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_echo_farming(55,5,char.Jinshi,
                                                            ech.field_set_cl_lt,ech.set_cl,ech.desired_mainstats_list_spectro_dps,
                                                            dmgfun.calculate_jinshi_combo_damage,is_support=False,save_plots=True)
# Out:
# 0.0 %  done
# Echo exp materials needed (golden):  19376.959999999995
# Estimated tacet field runs needed for exp:  4635.636363636363
# Estimated days to get that exp:  1158.9090909090908
#
# Tuners needed:  48100
# Estimated tacet field runs needed for tuners:  1924.0
# Estimated days to get that tuners:  481.0
# 20.0 %  done
# Echo exp materials needed (golden):  19878.999999999993
# Estimated tacet field runs needed for exp:  4755.741626794257
# Estimated days to get that exp:  1188.9354066985643
#
# Tuners needed:  49410
# Estimated tacet field runs needed for tuners:  1976.4
# Estimated days to get that tuners:  494.1
# 40.0 %  done
# Echo exp materials needed (golden):  18777.619999999995
# Estimated tacet field runs needed for exp:  4492.253588516745
# Estimated days to get that exp:  1123.0633971291863
#
# Tuners needed:  46720
# Estimated tacet field runs needed for tuners:  1868.8
# Estimated days to get that tuners:  467.2
# 60.0 %  done
# ...
