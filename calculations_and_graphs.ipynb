# %% [markdown]
# Calculation of havoc rover without equipped echoes with emerald of genesis r1

# %%
import echoes_main as ech
import additional_functions as addfun

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_rover_echo_farming(40,7,True,True)
# Out:
# 0.0 %  done
# Name:  Havoc Rover
#  Total hp:  17065.95
#  Total atk:  2524.0
#  Total def:  1259.0
#  Crit rate:  71.60000000000002 %
#  Crit damage:  262.3999999999998 %
#  Energy recharge:  121.99999999999997 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  8.6 %
#  Heavy attack damage bonus:  10.9 %
#  Ultimate damage bonus:  7.900000000000004 %
#  Skill damage bonus:  15.7 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [18.6]   sub_CD
#
# [9.3]   sub_CR
#
# [10.9]   sub_he_DMG
#
# [9.4]   sub_ATK%
#
# [40]   sub_ATK
#
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [16.2]   sub_CD
#
# [10.5]   sub_CR
#
# [9.4]   sub_ATK%
#
# [390]   sub_HP
#
# [8.6]   sub_HP%
#
# Name:  N11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [8.6]   sub_ba_DMG
#
# [16.2]   sub_CD
#
# [6.3]   sub_CR
#
# [11.6]   sub_ATK%
#
# [7.9]   sub_ult_DMG
#
# Name:  H05_a
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [7.1]   sub_sk_DMG
#
# [17.4]   sub_CD
#
# [8.1]   sub_CR
#
# [9.2]   sub_ER
#
# [9.4]   sub_ATK%
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [8.6]   sub_ATK%
#
# [8.6]   sub_sk_DMG
#
# [360]   sub_HP
#
# [50]   sub_ATK
#
# [8.1]   sub_CR
#
# 14.285714285714285 %  done
# Name:  Havoc Rover
#  Total hp:  15385.0
#  Total atk:  2641.0
#  Total def:  1407.562
#  Crit rate:  94.20000000000014 %
#  Crit damage:  238.2000000000003 %
#  Energy recharge:  112.8 %
#  Elemental damage bonus:  82 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  19.5 %
#  Heavy attack damage bonus:  0.0 %
#  Ultimate damage bonus:  31.599999999999987 %
#  Skill damage bonus:  35.9 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H81
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([22, 150], 'CR')
# Substats:
# [9.3]   sub_CR
#
# [7.1]   sub_sk_DMG
#
# [19.8]   sub_CD
#
# [9.4]   sub_ult_DMG
#
# [9.4]   sub_ATK%
#
# Name:  W60
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'ATK%')
# Substats:
# [9.9]   sub_CR
#
# [10.9]   sub_ba_DMG
#
# [7.9]   sub_ATK%
#
# [11.8]   sub_DEF%
#
# [18.6]   sub_CD
#
# Name:  W60
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [6.4]   sub_ult_DMG
#
# [11.6]   sub_sk_DMG
#
# [8.7]   sub_CR
#
# [17.4]   sub_CD
#
# [8.6]   sub_ba_DMG
#
# Name:  G03
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [8.6]   sub_sk_DMG
#
# [16.2]   sub_CD
#
# [10.9]   sub_ATK%
#
# [7.9]   sub_ult_DMG
#
# [7.5]   sub_CR
#
# Name:  G03
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [8.6]   sub_sk_DMG
#
# [16.2]   sub_CD
#
# [10.9]   sub_ATK%
#
# [7.9]   sub_ult_DMG
#
# [7.5]   sub_CR
#
# 28.57142857142857 %  done
# Name:  Havoc Rover
#  Total hp:  15895.0
#  Total atk:  2577.0
#  Total def:  1517.562
#  Crit rate:  70.40000000000019 %
#  Crit damage:  285.8000000000002 %
#  Energy recharge:  112.79999999999995 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  0.0 %
#  Heavy attack damage bonus:  8.6 %
#  Ultimate damage bonus:  1.0658141036401503e-14 %
#  Skill damage bonus:  16.5 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H08
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [15]   sub_CD
#
# [40]   sub_ATK
#
# [9.3]   sub_CR
#
# [11.8]   sub_DEF%
#
# [10.1]   sub_ATK%
#
# Name:  H53
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [21]   sub_CD
#
# [60]   sub_ATK
#
# [10.9]   sub_ATK%
#
# [6.9]   sub_CR
#
# [7.1]   sub_sk_DMG
#
# Name:  N13
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [50]   sub_ATK
#
# [9.9]   sub_CR
#
# [17.4]   sub_CD
#
# [40]   sub_DEF
#
# [7.9]   sub_ATK%
#
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.6]   sub_he_DMG
#
# [70]   sub_DEF
#
# [7.9]   sub_ATK%
#
# [6.9]   sub_CR
#
# [19.8]   sub_CD
#
# Name:  H81
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [9.4]   sub_sk_DMG
#
# [10.9]   sub_ATK%
#
# [18.6]   sub_CD
#
# [8.1]   sub_CR
#
# [510]   sub_HP
#
# 42.857142857142854 %  done
# Name:  Havoc Rover
#  Total hp:  15385.0
#  Total atk:  2718.0
#  Total def:  1573.4620000000004
#  Crit rate:  77.59999999999997 %
#  Crit damage:  280.99999999999994 %
#  Energy recharge:  112.8 %
#  Elemental damage bonus:  82 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  7.1 %
#  Heavy attack damage bonus:  17.999999999999968 %
#  Ultimate damage bonus:  17.3 %
#  Skill damage bonus:  16.500000000000018 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [9.4]   sub_sk_DMG
#
# [8.6]   sub_he_DMG
#
# [10.9]   sub_ATK%
#
# [10.5]   sub_CR
#
# [18.6]   sub_CD
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'ATK%')
# Substats:
# [10.5]   sub_CR
#
# [10.9]   sub_DEF%
#
# [19.8]   sub_CD
#
# [9.4]   sub_ATK%
#
# [7.1]   sub_ba_DMG
#
# Name:  H02
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [13.8]   sub_CD
#
# [40]   sub_ATK
#
# [9.3]   sub_CR
#
# [6.4]   sub_ult_DMG
#
# [11.6]   sub_ATK%
#
# Name:  G04
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [10.9]   sub_ATK%
#
# [15]   sub_CD
#
# [40]   sub_DEF
#
# [9.4]   sub_he_DMG
#
# [9.3]   sub_CR
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [10.9]   sub_ult_DMG
#
# [8.7]   sub_CR
#
# [10.9]   sub_DEF%
#
# [7.1]   sub_sk_DMG
#
# [19.8]   sub_CD
#
# 57.14285714285714 %  done
# Name:  Havoc Rover
#  Total hp:  17786.9
#  Total atk:  2529.0
#  Total def:  1299.0
#  Crit rate:  73.99999999999983 %
#  Crit damage:  280.9999999999999 %
#  Energy recharge:  121.20000000000022 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  0.0 %
#  Heavy attack damage bonus:  8.600000000000003 %
#  Ultimate damage bonus:  7.9 %
#  Skill damage bonus:  10.899999999999993 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [7.9]   sub_ult_DMG
#
# [15]   sub_CD
#
# [8.4]   sub_ER
#
# [9.9]   sub_CR
#
# [8.6]   sub_ATK%
#
# Name:  N11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [50]   sub_ATK
#
# [16.2]   sub_CD
#
# [7.9]   sub_ATK%
#
# [9.3]   sub_CR
#
# [8.6]   sub_HP%
#
# Name:  N11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [10.9]   sub_sk_DMG
#
# [17.4]   sub_CD
#
# [10.1]   sub_ATK%
#
# [540]   sub_HP
#
# [10.5]   sub_CR
#
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [7.5]   sub_CR
#
# [17.4]   sub_CD
#
# [40]   sub_DEF
#
# [60]   sub_ATK
#
# [10.9]   sub_ATK%
#
# Name:  S55
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.6]   sub_he_DMG
#
# [7.5]   sub_CR
#
# [9.4]   sub_ATK%
#
# [21]   sub_CD
#
# [8.6]   sub_HP%
#
# 71.42857142857143 %  done
# Name:  Havoc Rover
#  Total hp:  15815.0
#  Total atk:  2787.0
#  Total def:  1525.6200000000003
#  Crit rate:  57.19999999999986 %
#  Crit damage:  283.40000000000015 %
#  Energy recharge:  112.80000000000003 %
#  Elemental damage bonus:  82 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  25.10000000000001 %
#  Heavy attack damage bonus:  7.105427357601002e-15 %
#  Ultimate damage bonus:  9.399999999999997 %
#  Skill damage bonus:  19.500000000000004 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  S55
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'ATK%')
# Substats:
# [7.9]   sub_ba_DMG
#
# [9.9]   sub_CR
#
# [60]   sub_ATK
#
# [8.6]   sub_ATK%
#
# [17.4]   sub_CD
#
# Name:  H05_a
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [7.9]   sub_sk_DMG
#
# [9.3]   sub_CR
#
# [19.8]   sub_CD
#
# [40]   sub_ATK
#
# [7.1]   sub_ba_DMG
#
# Name:  H46
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [17.4]   sub_CD
#
# [8.7]   sub_CR
#
# [9]   sub_DEF%
#
# [8.6]   sub_ATK%
#
# [40]   sub_DEF
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [11.6]   sub_ATK%
#
# [430]   sub_HP
#
# [19.8]   sub_CD
#
# [11.6]   sub_sk_DMG
#
# [9.4]   sub_ult_DMG
#
# Name:  H05_a
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [10.1]   sub_ba_DMG
#
# [10.9]   sub_ATK%
#
# [15]   sub_CD
#
# [40]   sub_ATK
#
# [9]   sub_DEF%
#
# 85.71428571428571 %  done
# Name:  Havoc Rover
#  Total hp:  17008.75
#  Total atk:  2329.0
#  Total def:  1259.0
#  Crit rate:  74.59999999999992 %
#  Crit damage:  285.79999999999956 %
#  Energy recharge:  112.79999999999994 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  25.799999999999997 %
#  Heavy attack damage bonus:  10.9 %
#  Ultimate damage bonus:  0.0 %
#  Skill damage bonus:  27.39999999999999 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  S06
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [18.6]   sub_CD
#
# [8.6]   sub_ATK%
#
# [50]   sub_ATK
#
# [10.1]   sub_sk_DMG
#
# [9.9]   sub_CR
#
# Name:  H11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [40]   sub_ATK
#
# [16.2]   sub_CD
#
# [8.7]   sub_CR
#
# [8.6]   sub_ba_DMG
#
# [10.9]   sub_ATK%
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [21]   sub_CD
#
# [7.9]   sub_sk_DMG
#
# [8.7]   sub_CR
#
# [7.9]   sub_HP%
#
# [30]   sub_ATK
#
# Name:  H11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [7.1]   sub_HP%
#
# [9.4]   sub_sk_DMG
#
# [8.6]   sub_ba_DMG
#
# [19.8]   sub_CD
#
# [9.9]   sub_CR
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.1]   sub_CR
#
# [6.4]   sub_ATK%
#
# [8.6]   sub_ba_DMG
#
# [16.2]   sub_CD
#
# [10.9]   sub_he_DMG

# %%
Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
Rover_Havoc._apply_weapon_conditional_bonuses()
damage=[]

Rover_Havoc._total_attack+=(94/100)*Rover_Havoc._base_atk
Rover_Havoc._total_cd+=149
Rover_Havoc._total_cr+=52.5
Rover_Havoc._total_attack+=700
Rover_Havoc._ult_dmg+=58
Rover_Havoc._total_elem_dmg=112

Rover_Havoc.print_character_stats()

for i in range(1000):
    damage.append(ech.calculate_rover_combo_damage(Rover_Havoc))

print(damage)

fig,ax=plt.subplots()
ax.hist(damage)
ax.set(title='Number of occurances of specific damage with max stats, 1000 tries',xlabel='damage',ylabel='number of occurances')
plt.savefig('max damage.png',format='png')

print(np.average(damage))
# Out:
# Name:  Havoc Rover
#  Total hp:  10825
#  Total atk:  2880.0
#  Total def:  1259
#  Crit rate:  81.8 %
#  Crit damage:  299 %
#  Energy recharge:  112.8 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  0 %
#  Heavy attack damage bonus:  0 %
#  Ultimate damage bonus:  58 %
#  Skill damage bonus:  0 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  False
#  2pc set bonus applied:  False
#  5pc set bonus applied:  False
# [990018.2414592002, 920131.9428096, 768925.6702848002, 760215.2091264003, 957731.9847552002, 1013020.0458624002, 1003417.3744128001, 952634.9764224, 662999.0184576001, 716564.5330176002, 948901.3517952, 999872.3979648001, 954480.0331008, 981508.5786240002, 995447.5218432001, 960052.57056, 698703.3169920001, 952183.5871104001, 1027017.1263744002, 994659.0462720001, 939802.1548032002, 908223.1969536, 758742.4282752, 996826.3797888001, 929374.3051776002, 910103.3744256, 1012847.6284416001, 972131.4413568, 993234.1324032001, 960977.127744, 991033.5808512, 990667.5176448002, 959343.9420672001, 715827.0192768001, 1004474.4369408002, 971166.1238784001, 1020608.7277824001, 960718.7423232002, 943608.0613248, 964816.2523008, 727143.5716992001, 1035419.56992, 983118.2663808002, 1013203.5130368002, 993644.5550976001, 1014910.7687424002, 957666.3052032, 940908.0013056, 984814.4035584002, 1017605.0746368, 687217.6483199999, 1019658.0363264, 766877.1560064, 1013707.4459904002, 916989.5716992002, 997483.1982336001, 972814.