# %% [markdown]
# Calculation of havoc rover without equipped echoes with emerald of genesis r1

# %%
import echoes_main as ech
import additional_functions as addfun
import damage_functions as dmgfun


import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_rover_echo_farming(15,6,True,True)
# Out:
# damage new 2: 91007646.25034015 damage old: 89946631.01356646
# damage new 2: 109281528.25753248 damage old: 108111024.34302507
# damage new: 128512571.90332474 damage old: 127697730.50531115
# damage new: 128896414.28291698 damage old: 128660837.17083189
# damage new 2: 129368521.54704143 damage old: 128316089.57060526
# damage new 1: 130053601.31640077 damage old: 129511903.60365784
# damage new 2: 140111784.5086171 damage old: 130559606.25635907
# damage new 1: 143846845.22466224 damage old: 140370036.78980684
# damage new: 195859037.04698408 damage old: 179756548.02126163
# damage new: 196844471.78995666 damage old: 196126101.94798613
# damage new 2: 251520691.33061504 damage old: 243665713.46594003
# damage new 2: 254361199.31822586 damage old: 249361798.1123958
# damage new 1: 267908684.42514688 damage old: 256049102.9189996
# damage new: 295287304.89857435 damage old: 268983913.04366475
# damage new 2: 302078265.5250075 damage old: 290413802.3411663
# damage new 1: 304010914.3426965 damage old: 300966576.6979033
# damage new 1: 311076345.07645464 damage old: 300495705.08304614
# damage new 1: 318070443.55753237 damage old: 309075319.56646603
# damage new 2: 321548972.8267538 damage old: 317148553.2044407
# damage new 2: 326666007.6556092 damage old: 320275223.09513307
# 0.0 %  done
# Name:  Havoc Rover
#  Total hp:  16750.175
#  Total atk:  2699.0
#  Total def:  1396.231
#  Crit rate:  71.6 %
#  Crit damage:  278.6000000000001 %
#  Energy recharge:  112.8 %
#  Elemental damage bonus:  82 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  17.2 %
#  Heavy attack damage bonus:  17.999999999999986 %
#  Ultimate damage bonus:  10.1 %
#  Skill damage bonus:  17.199999999999996 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  R55
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [510]   sub_HP
#
# [17.4]   sub_CD
#
# [8.6]   sub_ATK%
#
# [7.9]   sub_HP%
#
# [7.5]   sub_CR
#
# Name:  H81
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [60]   sub_ATK
#
# [10.1]   sub_ATK%
#
# [17.4]   sub_CD
#
# [6.9]   sub_CR
#
# [8.6]   sub_sk_DMG
#
# Name:  H08
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [10.9]   sub_he_DMG
#
# [19.8]   sub_CD
#
# [9.3]   sub_CR
#
# [10.1]   sub_ult_DMG
#
# [7.1]   sub_ba_DMG
#
# Name:  G04
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [17.4]   sub_CD
#
# [10.9]   sub_DEF%
#
# [10.1]   sub_ba_DMG
#
# [10.1]   sub_ATK%
#
# [8.1]   sub_CR
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'ATK%')
# Substats:
# [10.1]   sub_ATK%
#
# [8.6]   sub_sk_DMG
#
# [12.6]   sub_CD
#
# [10.5]   sub_CR
#
# [7.1]   sub_he_DMG
#
# damage new 1: 116451919.14648992 damage old: 110852073.54588446
# damage new 2: 119726453.57026502 damage old: 116070180.8825135
# damage new 2: 129842339.15813278 damage old: 120163786.56154193
# damage new 1: 131442174.23877445 damage old: 129864968.15180978
# damage new 1: 136146847.66105044 damage old: 130529068.154421
# damage new: 139148310.26673672 damage old: 137530197.4538427
# damage new 2: 144125412.48403582 damage old: 140142430.89907458
# damage new 2: 159251460.17008603 damage old: 143239426.45864105
# damage new 1: 282465224.49813247 damage old: 272209015.4040863
# damage new 2: 290529336.8151143 damage old: 280705937.0610151
# damage new: 300112283.4272515 damage old: 292438079.71923155
# damage new 2: 310139223.8486492 damage old: 302008237.62873274
# damage new 2: 320088092.8002018 damage old: 307727159.08416706
# damage new 1: 323387933.0173354 damage old: 317348329.0375297
# damage new 1: 329153376.5448965 damage old: 320827831.38789934
# 16.666666666666664 %  done
# Name:  Havoc Rover
#  Total hp:  15385.0
#  Total atk:  2446.0
#  Total def:  1259.0
#  Crit rate:  71.60000000000004 %
#  Crit damage:  269.00000000000017 %
#  Energy recharge:  132.79999999999995 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  7.0999999999999925 %
#  Heavy attack damage bonus:  14.3 %
#  Ultimate damage bonus:  15.8 %
#  Skill damage bonus:  19.5 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  W60
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.1]   sub_CR
#
# [9.4]   sub_ATK%
#
# [7.9]   sub_ult_DMG
#
# [11.6]   sub_ER
#
# [17.4]   sub_CD
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [9.3]   sub_CR
#
# [16.2]   sub_CD
#
# [8.6]   sub_ATK%
#
# [7.9]   sub_he_DMG
#
# [9.4]   sub_sk_DMG
#
# Name:  H02
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [13.8]   sub_CD
#
# [50]   sub_ATK
#
# [7.1]   sub_ATK%
#
# [8.1]   sub_CR
#
# [7.1]   sub_ba_DMG
#
# Name:  G04
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [6.4]   sub_he_DMG
#
# [8.1]   sub_CR
#
# [8.4]   sub_ER
#
# [13.8]   sub_CD
#
# [8.6]   sub_ATK%
#
# Name:  H53
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [10.9]   sub_ATK%
#
# [13.8]   sub_CD
#
# [7.9]   sub_ult_DMG
#
# [8.7]   sub_CR
#
# [10.1]   sub_sk_DMG
#
# damage new 1: 128209834.74210341 damage old: 123905482.92382683
# damage new: 135462622.54896957 damage old: 127476402.59038301
# damage new 2: 140497205.20757145 damage old: 135398763.22485772
# damage new 2: 142740515.86408767 damage old: 140049687.4835555
# damage new 2: 143741854.35049367 damage old: 143296951.56615618
# damage new 2: 144255729.7595099 damage old: 143929082.7460301
# damage new: 199501829.74207056 damage old: 182246406.5907938
# damage new: 198623636.167905 damage old: 198232565.55535012
# damage new: 202502053.52479225 damage old: 200346167.61297882
# damage new 2: 246790213.94925174 damage old: 242460684.59080112
# damage new 1: 249553116.4835616 damage old: 244149287.1229162
# damage new: 260166253.5764508 damage old: 249106392.59848198
# damage new 2: 263246407.78398505 damage old: 261244789.6664203
# damage new 2: 278367123.75341314 damage old: 263137632.14717883
# damage new 2: 280781264.1312454 damage old: 279640984.44770753
# damage new 1: 287135750.96594286 damage old: 282866924.1572335
# damage new: 287978658.4139438 damage old: 284996168.680472
# damage new: 287772711.7605059 damage old: 285169819.32841104
# damage new 2: 286881217.6516676 damage old: 286513982.94944143
# damage new 1: 292170160.7092226 damage old: 287131478.3553178
# damage new 2: 299223773.8704851 damage old: 293292461.68326116
# damage new: 303480137.2381552 damage old: 298350067.784847
# damage new 2: 305623564.4813705 damage old: 300480410.8884562
# damage new 2: 314794469.7332029 damage old: 305808466.0139438
# damage new: 318914051.0632003 damage old: 315562937.31925774
# damage new: 322515712.93597686 damage old: 320128156.3882144
# damage new 1: 321232292.5100494 damage old: 320635195.62629133
# damage new 2: 328111645.51113516 damage old: 325835485.8074589
# 33.33333333333333 %  done
# Name:  Havoc Rover
#  Total hp:  15385.0
#  Total atk:  2839.0
#  Total def:  1299.0
#  Crit rate:  74.00000000000001 %
#  Crit damage:  229.79999999999998 %
#  Energy recharge:  132.0 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  8.600000000000007 %
#  Heavy attack damage bonus:  15.8 %
#  Ultimate damage bonus:  9.399999999999997 %
#  Skill damage bonus:  0 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.7]   sub_CR
#
# [17.4]   sub_CD
#
# [7.1]   sub_ATK%
#
# [8.6]   sub_ba_DMG
#
# [10]   sub_ER
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([33, 150], 'ATK%')
# Substats:
# [40]   sub_ATK
#
# [17.4]   sub_CD
#
# [8.6]   sub_ATK%
#
# [9.4]   sub_ult_DMG
#
# [9.3]   sub_CR
#
# Name:  N13
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [15]   sub_CD
#
# [7.9]   sub_he_DMG
#
# [40]   sub_ATK
#
# [8.7]   sub_CR
#
# [9.4]   sub_ATK%
#
# Name:  N13
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [15]   sub_CD
#
# [7.9]   sub_he_DMG
#
# [40]   sub_ATK
#
# [8.7]   sub_CR
#
# [9.4]   sub_ATK%
#
# Name:  H46
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [9.3]   sub_CR
#
# [9.4]   sub_ATK%
#
# [9.2]   sub_ER
#
# [40]   sub_DEF
#
# [15]   sub_CD
#
# damage new 2: 102683304.23881643 damage old: 102383847.9471852
# damage new 2: 138592180.24207222 damage old: 133106020.7617
# damage new 1: 143055596.38755724 damage old: 137923936.42759845
# damage new 1: 150283781.99872568 damage old: 142520960.66177446
# damage new 1: 160153314.48614565 damage old: 150187801.80766305
# damage new: 224471756.0112584 damage old: 216377150.1070062
# damage new: 226361948.17600387 damage old: 223896258.34860364
# damage new 1: 286702703.0435015 damage old: 283641214.5619044
# damage new 1: 296801035.6591089 damage old: 289153220.9112784
# damage new: 300289958.7933049 damage old: 296019480.5067974
# damage new 1: 304733086.33742344 damage old: 298029512.62675655
# damage new: 310572335.764135 damage old: 302981045.9214927
# 50.0 %  done
# Name:  Havoc Rover
#  Total hp:  15385.0
#  Total atk:  2706.0
#  Total def:  1520.8720000000003
#  Crit rate:  74.00000000000001 %
#  Crit damage:  252.80000000000004 %
#  Energy recharge:  124.39999999999996 %
#  Elemental damage bonus:  82 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  0.0 %
#  Heavy attack damage bonus:  0.0 %
#  Ultimate damage bonus:  40.5 %
#  Skill damage bonus:  19.5 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  S05
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [12.6]   sub_CD
#
# [8.6]   sub_ult_DMG
#
# [40]   sub_ATK
#
# [9.4]   sub_ATK%
#
# [8.7]   sub_CR
#
# Name:  H53
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.6]   sub_ATK%
#
# [9]   sub_DEF%
#
# [9.9]   sub_CR
#
# [8.6]   sub_sk_DMG
#
# [9.4]   sub_ult_DMG
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'ATK%')
# Substats:
# [11.8]   sub_DEF%
#
# [11.6]   sub_ult_DMG
#
# [9.3]   sub_CR
#
# [50]   sub_ATK
#
# [13.8]   sub_CD
#
# Name:  W31
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [10.9]   sub_ult_DMG
#
# [8.1]   sub_CR
#
# [15]   sub_CD
#
# [60]   sub_ATK
#
# [8.6]   sub_ATK%
#
# Name:  H80
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [40]   sub_ATK
#
# [11.6]   sub_ER
#
# [8.7]   sub_CR
#
# [17.4]   sub_CD
#
# [10.9]   sub_sk_DMG
#
# damage new 2: 68751780.83828507 damage old: 67241784.03771399
# damage new: 72172431.75022022 damage old: 69401230.18763308
# damage new 1: 77305716.97294484 damage old: 72553015.62984784
# damage new: 185970990.9885519 damage old: 183110842.95265603
# damage new 1: 261712360.62924635 damage old: 228764294.60290343
# damage new 1: 263974546.09607 damage old: 261935998.34043595
# damage new 2: 266940736.3547863 damage old: 262519020.14942002
# damage new: 274050135.1755844 damage old: 268921603.62068236
# damage new 1: 284314084.8307387 damage old: 274308127.5133565
# damage new: 297731087.4111948 damage old: 285003469.2370242
# damage new 1: 306146809.17857534 damage old: 295598450.61350214
# damage new 1: 310111385.54542816 damage old: 306626994.91527635
# damage new: 314733474.92888415 damage old: 311838169.1375375
# damage new: 316336007.00327736 damage old: 314063510.22433573
# damage new 1: 317569741.57386446 damage old: 313883675.29387844
# damage new 1: 321595118.2192038 damage old: 318835162.4301526
# damage new 1: 323383233.5713685 damage old: 321603153.545313
# 66.66666666666666 %  done
# Name:  Havoc Rover
#  Total hp:  17008.75
#  Total atk:  2449.0
#  Total def:  1384.9
#  Crit rate:  94.19999999999997 %
#  Crit damage:  233.4 %
#  Energy recharge:  129.6 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  7.9 %
#  Heavy attack damage bonus:  8.599999999999998 %
#  Ultimate damage bonus:  0 %
#  Skill damage bonus:  8.60000000000001 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H81
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([22, 150], 'CR')
# Substats:
# [8.6]   sub_sk_DMG
#
# [8.6]   sub_ATK%
#
# [40]   sub_ATK
#
# [8.1]   sub_CR
#
# [15]   sub_CD
#
# Name:  H11
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [9.2]   sub_ER
#
# [18.6]   sub_CD
#
# [7.9]   sub_ATK%
#
# [7.9]   sub_ba_DMG
#
# [8.1]   sub_CR
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [8.7]   sub_CR
#
# [7.6]   sub_ER
#
# [7.1]   sub_HP%
#
# [7.9]   sub_ATK%
#
# [18.6]   sub_CD
#
# Name:  R55
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [17.4]   sub_CD
#
# [10]   sub_DEF%
#
# [50]   sub_ATK
#
# [8.7]   sub_CR
#
# [6.4]   sub_ATK%
#
# Name:  S05
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [7.9]   sub_HP%
#
# [9.3]   sub_CR
#
# [8.6]   sub_he_DMG
#
# [13.8]   sub_CD
#
# [10.1]   sub_ATK%
#
# damage new 1: 107204461.10999365 damage old: 99684897.19083476
# damage new 2: 149123147.62323058 damage old: 144684370.84390557
# damage new 2: 153694482.42666233 damage old: 149988164.60312223
# damage new: 205393598.9412844 damage old: 194152612.69498152
# damage new: 205134748.1187152 damage old: 203337975.16993728
# damage new 1: 263084477.5539942 damage old: 251495603.67107257
# damage new 2: 268349076.71506524 damage old: 262913005.7999027
# damage new: 273585209.13765925 damage old: 268790785.9464808
# damage new: 272838684.86100715 damage old: 271752021.98252606
# damage new: 280786729.98238325 damage old: 277052832.7754465
# damage new: 280259613.9031729 damage old: 278023142.37861115
# damage new: 285759396.28387856 damage old: 278912880.0345792
# damage new: 295188119.2782869 damage old: 284940582.9516576
# damage new: 295254204.5719947 damage old: 295249571.1057872
# damage new: 296456842.9762048 damage old: 291510370.5722639
# damage new 1: 297865748.43402344 damage old: 292494470.52964044
# damage new 2: 308652228.7056265 damage old: 295736418.39581406
# damage new 1: 322467663.25655484 damage old: 310359568.5975233
# damage new 1: 325401207.2384561 damage old: 323229009.22624356
# damage new 1: 330294391.8521225 damage old: 324898123.6149365
# damage new 2: 336925455.05075246 damage old: 330030918.92953277
# 83.33333333333334 %  done
# Name:  Havoc Rover
#  Total hp:  16635.95
#  Total atk:  2454.0
#  Total def:  1309.0
#  Crit rate:  71.59999999999997 %
#  Crit damage:  276.2 %
#  Energy recharge:  120.4 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  27.4 %
#  Heavy attack damage bonus:  0.0 %
#  Ultimate damage bonus:  7.105427357601002e-15 %
#  Skill damage bonus:  19.499999999999993 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  True
#  2pc set bonus applied:  True
#  5pc set bonus applied:  True
# Name:  H81
#  Set:  HavocDMG_s
#  Cost:  4
#  Mainstats:  ([44, 150], 'CD')
# Substats:
# [15]   sub_CD
#
# [7.1]   sub_ATK%
#
# [9.3]   sub_CR
#
# [10.1]   sub_ba_DMG
#
# [7.6]   sub_ER
#
# Name:  G03
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [18.6]   sub_CD
#
# [10.1]   sub_sk_DMG
#
# [50]   sub_DEF
#
# [8.1]   sub_CR
#
# [7.9]   sub_ATK%
#
# Name:  S55
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [50]   sub_ATK
#
# [8.7]   sub_CR
#
# [10.1]   sub_ATK%
#
# [320]   sub_HP
#
# [16.2]   sub_CD
#
# Name:  H49
#  Set:  HavocDMG_s
#  Cost:  3
#  Mainstats:  ([30, 100], 'HavocDMG')
# Substats:
# [9.4]   sub_ba_DMG
#
# [6.3]   sub_CR
#
# [15]   sub_CD
#
# [9.4]   sub_ATK%
#
# [9.4]   sub_sk_DMG
#
# Name:  G04
#  Set:  HavocDMG_s
#  Cost:  1
#  Mainstats:  ([18, 2280], 'ATK%')
# Substats:
# [7.9]   sub_ba_DMG
#
# [10.9]   sub_ATK%
#
# [8.6]   sub_HP%
#
# [9.9]   sub_CR
#
# [17.4]   sub_CD

# %%
Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
Rover_Havoc._apply_weapon_conditional_bonuses()
damage=[]

Rover_Havoc._total_attack+=(94/100)*Rover_Havoc._base_atk
Rover_Havoc._total_cd+=149
Rover_Havoc._total_cr+=52.5
Rover_Havoc._total_attack+=700
Rover_Havoc._ult_dmg+=58
Rover_Havoc._total_elem_dmg=112

Rover_Havoc.print_character_stats()

for i in range(1000):
    damage.append(dmgfun.calculate_rover_combo_damage(Rover_Havoc))

print(damage)

fig,ax=plt.subplots()
ax.hist(damage)
ax.set(title='Number of occurances of specific damage with max stats, 1000 tries',xlabel='damage',ylabel='number of occurances')
plt.savefig('max damage.png',format='png')

fig,ax=plt.subplots()
ax.plot(np.cumsum(list_of_days),average_damages_through_days,'.')
titstr='Damage during '+str(np.sum(list_of_days))+' days with max theoretical damage and its average for reference'
ax.set(title=titstr,xlabel='day',ylabel='damage')
ax.plot(10,max(damage),'ro')
ax.plot(10,np.mean(damage),'mo')
plt.savefig('Output/Graphs/'+titstr+'.png')
# Out:
# Name:  Havoc Rover
#  Total hp:  10825
#  Total atk:  2880.0
#  Total def:  1259
#  Crit rate:  81.8 %
#  Crit damage:  299 %
#  Energy recharge:  112.8 %
#  Elemental damage bonus:  112 %
#  Healing bonus:  0 %
#  Basic attack damage bonus:  0 %
#  Heavy attack damage bonus:  0 %
#  Ultimate damage bonus:  58 %
#  Skill damage bonus:  0 %
#  Weapon:  emerald_of_genesis
#  Weapon bonuses applied:  True
#  Echo bonus applied:  False
#  2pc set bonus applied:  False
#  5pc set bonus applied:  False
# [639495.6194304, 980755.95744, 963670.1039999999, 691036.7824512002, 1004280.3097344002, 1022899.6947456002, 927550.4768640001, 1050184.745856, 1051685.9076096, 1020384.8900352002, 1052830.726272, 940969.8982656001, 920927.9606400002, 947268.1661183999, 1018140.9189120001, 1033782.3265536001, 966689.2313856, 988653.5281152001, 1019285.7375744001, 905666.3023104, 969914.9570688001, 1015226.3515392002, 953643.7134720002, 1004147.8043904001, 932796.7714944, 893206.6276608, 1040340.1031424002, 989272.7040384002, 981885.2101632002, 979438.1482368001, 956186.9220096, 955760.5436543999, 979003.1043072001, 1033901.9940096003, 934111.6463232002, 783678.0083328002, 882729.2375424, 731605.8381696, 966175.4636928, 895305.2784768002, 1053975.5449344, 725906.6411904, 982921.9842432002, 910160.3654784001, 694024.9613568, 952676.0118144, 947729.91744, 902193.8140799999, 976373.7214464003, 955586.1547008002, 985513.7933568001, 757848.4527744002, 1017765.5023872002, 1002957.3195264002, 768311.2168704002, 762874.4859264002, 958291.9688448001, 979801.6897152003, 973540.4224896001, 706902.9677568, 1009262.9233152001, 1028145.9893760001, 977332.5512064003, 940496.0655744002, 901447.7035392, 987710.3789184002, 1051329.5645184, 992826.8274816001, 749579.064768, 738200.6841600001, 655531.4024064001, 1007136.8315136001, 1012361.6914560001, 1024264.7748864002, 999952.3367424001, 1041455.6697600002, 1031954.0737536002, 1027352.0347776002, 940237.4050560001, 975105.3839616001, 978652.6987392001, 987774.2703360001, 948112.4177280001, 970211.0079360001, 976041.9078912, 994327.9892352002, 713564.4790656001, 1002943.1520000001, 729760.3000704001, 993878.3880576002, 917458.8652800001, 979759.5997824002, 975818.0701440001, 977100.3000576001, 1008845.0500608, 948723.1802496001, 987473.7032832, 739112.976576, 978601.4618112001, 943179.8948352, 925372.8501120001, 726451.5407616001, 1039253.7885696002, 1022881.9509504002, 1001411.4085632, 958551.4088064001, 754445.0369664001, 1001139.7267584001, 735495.9245568002, 961337.8953216, 756268.8652800003, 755810.1171072002, 1026732.5837568002, 1042600.4884224001, 911837.1541248001, 960706.7526528002, 984790.0574208001, 702889.6376448001, 920170.0667520001, 956632.8322944001, 1011218.2024320002, 912403.9468800002, 1012831.2142848002, 996436.6123392002, 1026317.7365760002, 1043954.0603136002, 1021397.2033536, 961333.4708352, 943920.9848448, 1021558.9607424001, 951174.8500608001, 743800.410432, 948236.0511744003, 956688.4020096001, 978241.1527296001, 943396.0986240001, 933096.7883520002, 1009560.3038208002, 978128.8441344001, 989958.4077312002, 1001144.1512448001, 965660.1141888001, 933050.7324288001, 1008622.9087488002, 911517.2385407999, 1006700.2745472002, 1011492.3601152, 974185.7326848002, 739155.5479296001, 1000622.9329920001, 980308.2590208, 736970.4706176001, 1026601.4080512002, 735381.5527296001, 1004889.2841216001, 999359.3180160002, 967665.4839936, 945786.4445952, 772360.1262720003, 1047715.6073472002, 958433.8045824, 953192.4158592002, 951276.4069248002, 961651.9650816001, 708196.2474240001, 772570.2091392002, 976055.2272000001, 1047715.6073472, 910447.3610496001, 997217.2705536, 966719.4462720001, 948901.3517952, 723015.7551360001, 972992.588544, 796259.0468736002, 984368.6078976002, 982106.8929792001, 964840.5984384002, 709498.2843648003, 946805.8416768, 1019136.8180736001, 962241.1324416001, 1030168.3693824002, 1022496.3558144001, 937510.8210432001, 1018555.3075968002, 954894.0320640001, 877491.4480128002, 1037888.7084288, 895732.5738240001, 899877.1942656001, 1043923.4786304003, 1005348.0322944003, 771305.7230208002, 767649.6759168002, 953999.6897664004, 762711.3988992001, 1038808.3597056001, 1034423.2122624002, 919130.7480191999, 961300.0464768001, 995681.5611264001, 1040398.6072320002, 1026779.5795968001, 982226.9272320002, 966279.0837888002, 988622.9464320001, 986357.7698688003, 1024933.2162048002, 939246.2971776001, 1026050.4792576001, 1004380.0555392001, 1002052.2942720001, 931667.9084928, 760328.2513152 ...
