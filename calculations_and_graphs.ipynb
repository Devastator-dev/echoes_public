# %% [markdown]
# Calculation of havoc rover without equipped echoes with emerald of genesis r1

# %%
import echoes_main as ech
import additional_functions as addfun
import damage_functions as dmgfun


import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import cProfile as cp
import characters as char

# %%
average_damages_through_days,percentages_of_max,list_of_days=addfun.simulate_dps_echo_farming(15,5,char.Xiangli_Yao,
                                                            ech.field_set_vt_mr,ech.set_vt,ech.desired_mainstats_list_electro_dps,dmgfun.calculate_xiangli_combo_damage,save_plots=True)
# Out:
# 0.0 %  done
# Echo exp materials needed (golden):  5007.400000000001
# Estimated tacet field runs needed for exp:  1197.9425837320575
# Estimated days to get that exp:  299.4856459330144
#
# Tuners needed:  12400
# Estimated tacet field runs needed for tuners:  496.0
# Estimated days to get that tuners:  124.0
# 20.0 %  done
# Echo exp materials needed (golden):  5417.320000000001
# Estimated tacet field runs needed for exp:  1296.0095693779906
# Estimated days to get that exp:  324.00239234449765
#
# Tuners needed:  13450
# Estimated tacet field runs needed for tuners:  538.0
# Estimated days to get that tuners:  134.5
# 40.0 %  done
# Echo exp materials needed (golden):  5482.000000000002
# Estimated tacet field runs needed for exp:  1311.4832535885173
# Estimated days to get that exp:  327.8708133971293
#
# Tuners needed:  13600
# Estimated tacet field runs needed for tuners:  544.0
# Estimated days to get that tuners:  136.0
# 60.0 %  done
# Echo exp materials needed (golden):  4987.38
# Estimated tacet field runs needed for exp:  1193.153110047847
# Estimated days to get that exp:  298.2882775119617
#
# Tuners needed:  12390
# Estimated tacet field runs needed for tuners:  495.6
# Estimated days to get that tuners:  123.9
# 80.0 %  done
# Echo exp materials needed (golden):  5873.3
# Estimated tacet field runs needed for exp:  1405.0956937799044
# Estimated days to get that exp:  351.2739234449761
#
# Tuners needed:  14630
# Estimated tacet field runs needed for tuners:  585.2
# Estimated days to get that tuners:  146.3

# %%
"""'Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
Rover_Havoc._apply_weapon_conditional_bonuses()
damage=[]

Rover_Havoc._total_attack+=(94/100)*Rover_Havoc._base_atk
Rover_Havoc._total_cd+=149
Rover_Havoc._total_cr+=52.5
Rover_Havoc._total_attack+=700
Rover_Havoc._ult_dmg+=58
Rover_Havoc._total_elem_dmg=112

Rover_Havoc.print_character_stats()

for i in range(1000):
    damage.append(dmgfun.calculate_hrover_combo_damage(Rover_Havoc))

print(damage)

fig,ax=plt.subplots()
ax.hist(damage,bins=30)
ax.set(title='Number of occurances of specific damage with max stats, 1000 tries',xlabel='damage',ylabel='number of occurances')
plt.savefig('Output/Graphs/max damage.png',format='png')

fig,ax=plt.subplots()
ax.plot(np.cumsum(list_of_days),average_damages_through_days,'.')
titstr='Damage during '+str(np.sum(list_of_days))+' days with max theoretical damage and its average for reference, hrover'
ax.set(title=titstr,xlabel='day',ylabel='damage')
ax.plot(10,max(damage),'ro')
ax.plot(10,np.mean(damage),'mo')
plt.savefig('Output/Graphs/'+titstr+'.png')"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Rover_Havoc=ech.Character(ech.set_sse,10825,413,1259,125,5,150,ech.weapon_emerald_of_genesis,'Havoc Rover',ech.main_ha_dmg,0,12,12)
#       2 Rover_Havoc._apply_weapon_conditional_bonuses()
#       3 damage=[]
#
# NameError: name 'ech' is not defined
